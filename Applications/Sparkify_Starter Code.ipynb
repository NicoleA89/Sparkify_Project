# %% [markdown]
# # Sparkify Project Workspace
# This workspace contains a tiny subset (128MB) of the full dataset available (12GB). Feel free to use this workspace to build your project, or to explore a smaller subset with Spark before deploying your cluster on the cloud. Instructions for setting up your Spark cluster is included in the last lesson of the Extracurricular Spark Course content.
#
# You can follow the steps below to guide your data analysis and model building portion of this project.

# %%
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

from pyspark.sql import SparkSession, SQLContext
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier, GBTClassifier
from pyspark.ml.feature import RegexTokenizer, CountVectorizer, \
    IDF, StringIndexer, VectorAssembler, Normalizer, StandardScaler
from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType

# %%
# Read the relevant data
df = pd.read_csv("mini_sparkify_event_data.json")

# %%
# Take a look at the dataset
df.head()
# Out:
#                     {"ts":1538352117000   userId:"30"     sessionId:29  \
# {"ts":1538352180000          userId:"9"   sessionId:8  page:"NextSong"
# {"ts":1538352394000         userId:"30"  sessionId:29  page:"NextSong"
# {"ts":1538352416000          userId:"9"   sessionId:8  page:"NextSong"
# {"ts":1538352676000         userId:"30"  sessionId:29  page:"NextSong"
# {"ts":1538352678000          userId:"9"   sessionId:8  page:"NextSong"
#
#                       page:"NextSong" auth:"Logged In" method:"PUT"  \
# {"ts":1538352180000  auth:"Logged In"     method:"PUT"   status:200
# {"ts":1538352394000  auth:"Logged In"     method:"PUT"   status:200
# {"ts":1538352416000  auth:"Logged In"     method:"PUT"   status:200
# {"ts":1538352676000  auth:"Logged In"     method:"PUT"   status:200
# {"ts":1538352678000  auth:"Logged In"     method:"PUT"   status:200
#
#                        status:200      level:"paid"  \
# {"ts":1538352180000  level:"free"  itemInSession:79
# {"ts":1538352394000  level:"paid"  itemInSession:51
# {"ts":1538352416000  level:"free"  itemInSession:80
# {"ts":1538352676000  level:"paid"  itemInSession:52
# {"ts":1538352678000  level:"free"  itemInSession:81
#
#                                       itemInSession:50 location:"Bakersfield  \
# {"ts":1538352180000  location:"Boston-Cambridge-Newton                MA-NH"
# {"ts":1538352394000              location:"Bakersfield                   CA"
# {"ts":1538352416000  location:"Boston-Cambridge-Newton                MA-NH"
# {"ts":1538352676000              location:"Bakersfield                   CA"
# {"ts":1538352678000  location:"Boston-Cambridge-Newton                MA-NH"
#
#                                                                    CA"  \
# {"ts":1538352180000  userAgent:"\"Mozilla/5.0 (Windows NT 6.1; WOW6...
# {"ts":1538352394000  userAgent:"Mozilla/5.0 (Windows NT 6.1; WOW64;...
# {"ts":1538352416000  userAgent:"\"Mozilla/5.0 (Windows NT 6.1; WOW6...
# {"ts":1538352676000  userAgent:"Mozilla/5.0 (Windows NT 6.1; WOW64;...
# {"ts":1538352678000  userAgent:"\"Mozilla/5.0 (Windows NT 6.1; WOW6...
#
#                     userAgent:"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0"  \
# {"ts":1538352180000   like Gecko) Chrome/37.0.2062.103 Safari/537.3...
# {"ts":1538352394000                                 lastName:"Freeman"
# {"ts":1538352416000   like Gecko) Chrome/37.0.2062.103 Safari/537.3...
# {"ts":1538352676000                                 lastName:"Freeman"
# {"ts":1538352678000   like Gecko) Chrome/37.0.2062.103 Safari/537.3...
#
#                     lastName:"Freeman"           firstName:"Colin"  \
# {"ts":1538352180000    lastName:"Long"           firstName:"Micah"
# {"ts":1538352394000  firstName:"Colin"  registration:1538173362000
# {"ts":1538352416000    lastName:"Long"           firstName:"Micah"
# {"ts":1538352676000  firstName:"Colin"  registration:1538173362000
# {"ts":1538352678000    lastName:"Long"           firstName:"Micah"
#
#                      registration:1538173362000             gender:"M"  \
# {"ts":1538352180000  registration:1538331630000             gender:"M"
# {"ts":1538352394000                  gender:"M"  artist:"Adam Lambert"
# {"ts":1538352416000  registration:1538331630000             gender:"M"
# {"ts":1538352676000                  gender:"M"     artist:"Daft Punk"
# {"ts":1538352678000  registration:1538331630000             gender:"M"
#
#                                   artist:"Martha Tilston"  \
# {"ts":1538352180000             artist:"Five Iron Frenzy"
# {"ts":1538352394000              song:"Time For Miracles"
# {"ts":1538352416000                       artist:"Enigma"
# {"ts":1538352676000  song:"Harder Better Faster Stronger"
# {"ts":1538352678000     artist:"The All-American Rejects"
#
#                                        song:"Rockpools"  length:277.89016}
# {"ts":1538352180000                       song:"Canada"  length:236.09424}
# {"ts":1538352394000                    length:282.8273}                NaN
# {"ts":1538352416000  song:"Knocking On Forbidden Doors"  length:262.71302}
# {"ts":1538352676000                   length:223.60771}                NaN
# {"ts":1538352678000               song:"Don't Leave Me"  length:208.29995}

# %%
# create a Spark session

# %% [markdown]
# # Load and Clean Dataset
# In this workspace, the mini-dataset file is `mini_sparkify_event_data.json`. Load and clean the dataset, checking for invalid or missing data - for example, records without userids or sessionids.

# %% [markdown]
# # Exploratory Data Analysis
# When you're working with the full dataset, perform EDA by loading a small subset of the data and doing basic manipulations within Spark. In this workspace, you are already provided a small subset of data you can explore.
#
# ### Define Churn
#
# Once you've done some preliminary analysis, create a column `Churn` to use as the label for your model. I suggest using the `Cancellation Confirmation` events to define your churn, which happen for both paid and free users. As a bonus task, you can also look into the `Downgrade` events.
#
# ### Explore Data
# Once you've defined churn, perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned. You can start by exploring aggregates on these two groups of users, observing how much of a specific action they experienced per a certain time unit or number of songs played.

# %% [markdown]
# # Feature Engineering
# Once you've familiarized yourself with the data, build out the features you find promising to train your model on. To work with the full dataset, you can follow the following steps.
# - Write a script to extract the necessary features from the smaller subset of data
# - Ensure that your script is scalable, using the best practices discussed in Lesson 3
# - Try your script on the full data set, debugging your script if necessary
#
# If you are working in the classroom workspace, you can just extract features based on the small subset of data contained here. Be sure to transfer over this work to the larger dataset when you work on your Spark cluster.

# %% [markdown]
# # Modeling
# Split the full dataset into train, test, and validation sets. Test out several of the machine learning methods you learned. Evaluate the accuracy of the various models, tuning parameters as necessary. Determine your winning model based on test accuracy and report results on the validation set. Since the churned users are a fairly small subset, I suggest using F1 score as the metric to optimize.

# %% [markdown]
# # Final Steps
# Clean up your code, adding comments and renaming variables to make the code easier to read and maintain. Refer to the Spark Project Overview page and Data Scientist Capstone Project Rubric to make sure you are including all components of the capstone project and meet all expectations. Remember, this includes thorough documentation in a README file in a Github repository, as well as a web app or blog post.
